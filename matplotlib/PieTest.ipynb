# %%
import matplotlib
from matplotlib import pyplot as plt, font_manager
import matplotlib
my_font = font_manager.FontProperties(fname='C:\Windows\Fonts\STSONG.TTF', size=14)

label_list = ['第一部分', '第二部分', 'three']
size = [50,30,20]
color = ['red' ,'blue', 'green']
explode = [0, 0.05, 0] # 突出值

matplotlib.rcParams['font.sans-serif'] = ['SimHei']
pathces,l_text, p_text = plt.pie(size, explode=explode, colors=color, labels = label_list,labeldistance=1.1,autopct="%1.1f%%", shadow=False, startangle=90,pctdistance=0.6)
plt.axis("equal")# 横轴纵轴距离
plt.legend()
plt.show()
